# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
car_crash= pd.read_csv(r"C:\Users\Subhanghi\Downloads\car_crashes.csv")
car_crash.head(20)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
car_crash.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
car_crash.describe().transpose()
# Out:
#                 count        mean         std      min       25%      50%  \
# total            51.0   15.790196    4.122002    5.900   12.7500   15.600
# speeding         51.0    4.998196    2.017747    1.792    3.7665    4.608
# alcohol          51.0    4.886784    1.729133    1.593    3.8940    4.554
# not_distracted   51.0   13.573176    4.508977    1.760   10.4780   13.857
# no_previous      51.0   14.004882    3.764672    5.900   11.3480   13.775
# ins_premium      51.0  886.957647  178.296285  641.960  768.4300  858.970
# ins_losses       51.0  134.493137   24.835922   82.750  114.6450  136.050
#
#                      75%       max
# total             18.500    23.900
# speeding           6.439     9.450
# alcohol            5.604    10.038
# not_distracted    16.140    23.661
# no_previous       16.755    21.280
# ins_premium     1007.945  1301.520
# ins_losses       151.870   194.780

# %%
plt.hist(car_crash['alcohol'])
plt.show()

# %%
car_crash.boxplot(column='alcohol',by='not_distracted')
# Out:
# <Axes: title={'center': 'alcohol'}, xlabel='not_distracted'>

# %%
speeding=[7.332,7.421,6.51,4.032,4.2,5.032,4.968,6.156,2.006,3.759,2.964,9.45,5.508,4.608,3.625,2.669,4.806,4.066,7.175]

car_crash.plot.pie(y='speeding',figsize=(5,5),legend=False)
# Out:
# <Axes: ylabel='speeding'>

# %%
car_crash.plot.scatter(x='alcohol',y='speeding')
plt.grid(True)
